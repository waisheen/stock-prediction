# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
from torch.nn.functional import softmax
import torch
import yfinance as yf
import psycopg2

# %%
# Input DB params
params = {
    'dbname':
    'user': 
    'password': 
    'host': 
    'port': 
}

conn = psycopg2.connect(**params)
cur = conn.cursor()

tweet_query = """
INSERT INTO Tweet_Headline (company_id, content, date) VALUES (%s, %s, %s) RETURNING tweet_id;
"""
analysis_query = """
INSERT INTO Analysis (tweet_id, sentiment_score, sentiment_label) VALUES (%s, %s, %s);
"""

# %%
# Get the company_id if it exists, add the company_id if not
def get_or_create_company_id(ticker_symbol, cur):
    # Check if the company exists
    cur.execute("SELECT company_id FROM company WHERE ticker_symbol = %s", (ticker_symbol,))
    result = cur.fetchone()
    
    if result:
        return result  # Return existing company_id
    else:
        # Get company info
        company_info = get_stock_info(ticker_symbol)
        cur.execute("INSERT INTO company (company_name, ticker_symbol, sector) VALUES (%s, %s, %s) RETURNING company_id",
                    (company_info['Name'], ticker_symbol, company_info['Sector']))
        company_id = cur.fetchone()[0]
        return company_id

# %%
# include stocks and news you want to extract
stocks = ['AMZN', 'TSLA', 'NVDA', 'AAPL', 'MSFT', 'META']
news = {}

for stock in stocks:
    url = f'https://finviz.com/quote.ashx?t={stock}&p=d'
    request = Request(url=url, headers={'user-agent': 'news_scraper'})
    response = urlopen(request)
    
    # parse the HTML content
    html = BeautifulSoup(response, features='html.parser')
    finviz_news_table = html.find(id='news-table')
    news[stock] = finviz_news_table

# %%
# helper function to parse datetime to a standardized format
def parse_datetime(datetime_str, current_date):
    if 'Today' in datetime_str or datetime_str.count('-') == 0:
        date_part = current_date.strftime('%b-%d-%y')
        time_part = datetime_str.replace('Today', '').strip()
    else:
        # Split into date and time parts for explicit dates
        date_part, time_part = datetime_str.split(' ')
        # Update the current date to this new date
        current_date = datetime.strptime(date_part, '%b-%d-%y')  # Assuming year 2024 for example purposes

    # Convert AM/PM times to 24-hour format and return standardized datetime string
    full_datetime_str = f"{date_part} {time_part}"
    full_datetime = datetime.strptime(full_datetime_str, '%b-%d-%y %I:%M%p')
    
    return full_datetime.strftime('%b-%d-%y %H:%M'), current_date

# %%
# extract headers and timestamp
news_extracted = []
current_date = datetime.now()

for stock, news_item in news.items():
    for row in news_item.findAll('tr'):
        try:
            headline = row.find('a', class_='tab-link-news').getText().strip() # headline
            datetime_str = row.find('td', align='right').text.strip() # date of article
            standardized_datetime, current_date = parse_datetime(datetime_str, current_date)
            source = row.find('div', class_='news-link-right').span.text.strip('()') # source of article
            news_extracted.append([stock, standardized_datetime, headline, source])
        except Exception as e:
            print(f"Error parsing: {e}")
        
# convert to dataframe
df = pd.DataFrame(news_extracted, columns=['Stock', 'Date', 'Headline', 'Source'])
df
# Out:
#     Stock             Date                                           Headline  \
# 0    AMZN  Apr-12-24 04:00  A Once-in-a-Generation Investment Opportunity:...
# 1    AMZN  Apr-12-24 03:22  Amazon, eyeing up AI, adds Andrew Ng to its bo...
# 2    AMZN  Apr-11-24 20:53       Amazon hosts pet extravaganza for third year
# 3    AMZN  Apr-11-24 17:53  Snowflake Stock Jumps as KeyBanc Initiates Cov...
# 4    AMZN  Apr-11-24 17:45  Amazon CEO Andy Jassy touts AI push in shareho...
# ..    ...              ...                                                ...
# 595  META  Apr-04-24 12:14        Why Meta Platforms Stock Was Climbing Today
# 596  META  Apr-04-24 10:23  Meta Platforms Stock Has 15% Upside, According...
# 597  META  Apr-04-24 09:08              5 Stocks Hedge Funds Are Investing In
# 598  META  Apr-04-24 07:05  Meta Platforms (META) Rose on Better-Than-Expe...
# 599  META  Apr-04-24 06:35  Forget Nvidia: This "Fab Four" Stock Is a Barg...
#
#               Source
# 0        Motley Fool
# 1         TechCrunch
# 2    Chain Store Age
# 3       Investopedia
# 4       Fox Business
# ..               ...
# 595      Motley Fool
# 596      Motley Fool
# 597   Insider Monkey
# 598   Insider Monkey
# 599      Motley Fool
#
# [600 rows x 4 columns]

# %%
model_name = "ahmedrachid/FinancialBERT-Sentiment-Analysis"
tokenizer = AutoTokenizer.from_pretrained(model_name)
sentiment_pipeline = pipeline("sentiment-analysis", model=model_name, tokenizer=tokenizer)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
print(device)
# Out:
# cuda

# %%
df['Sentiment'] = df['Headline'].apply(lambda x: sentiment_pipeline(x))
df.head()
# Out:
#   Stock             Date                                           Headline  \
# 0  AMZN  Apr-12-24 04:00  A Once-in-a-Generation Investment Opportunity:...
# 1  AMZN  Apr-12-24 03:22  Amazon, eyeing up AI, adds Andrew Ng to its bo...
# 2  AMZN  Apr-11-24 20:53       Amazon hosts pet extravaganza for third year
# 3  AMZN  Apr-11-24 17:53  Snowflake Stock Jumps as KeyBanc Initiates Cov...
# 4  AMZN  Apr-11-24 17:45  Amazon CEO Andy Jassy touts AI push in shareho...
#
#             Source                                          Sentiment
# 0      Motley Fool  [{'label': 'neutral', 'score': 0.9996267557144...
# 1       TechCrunch  [{'label': 'neutral', 'score': 0.9979020357131...
# 2  Chain Store Age  [{'label': 'neutral', 'score': 0.9998151659965...
# 3     Investopedia  [{'label': 'neutral', 'score': 0.9930877089500...
# 4     Fox Business  [{'label': 'neutral', 'score': 0.9988156557083...

# %%
def extract_label(row):
    return row[0]['label']

def extract_score(row):
    return row[0]['score']

df[['sentiment_label']] = df['Sentiment'].apply(lambda x: pd.Series(extract_label(x)))
df[['sentiment_score']] = df['Sentiment'].apply(lambda x: pd.Series(extract_score(x)))
df.head()
# Out:
#   Stock             Date                                           Headline  \
# 0  AMZN  Apr-12-24 04:00  A Once-in-a-Generation Investment Opportunity:...
# 1  AMZN  Apr-12-24 03:22  Amazon, eyeing up AI, adds Andrew Ng to its bo...
# 2  AMZN  Apr-11-24 20:53       Amazon hosts pet extravaganza for third year
# 3  AMZN  Apr-11-24 17:53  Snowflake Stock Jumps as KeyBanc Initiates Cov...
# 4  AMZN  Apr-11-24 17:45  Amazon CEO Andy Jassy touts AI push in shareho...
#
#             Source                                          Sentiment  \
# 0      Motley Fool  [{'label': 'neutral', 'score': 0.9996267557144...
# 1       TechCrunch  [{'label': 'neutral', 'score': 0.9979020357131...
# 2  Chain Store Age  [{'label': 'neutral', 'score': 0.9998151659965...
# 3     Investopedia  [{'label': 'neutral', 'score': 0.9930877089500...
# 4     Fox Business  [{'label': 'neutral', 'score': 0.9988156557083...
#
#   sentiment_label  sentiment_score
# 0         neutral         0.999627
# 1         neutral         0.997902
# 2         neutral         0.999815
# 3         neutral         0.993088
# 4         neutral         0.998816

# %%
for index, row in df.iterrows():
    company_id = get_or_create_company_id(row['Stock'], cur)
    cur.execute(tweet_query, (company_id, row['Headline'], row['Date']))
    tweet_id = cur.fetchone()[0]  # Get the generated tweet_id
    
    # Insert into Analysis table
    cur.execute(analysis_query, (tweet_id, row['sentiment_score'], row['sentiment_label']))

conn.commit()

# %%
cur.execute("SELECT * FROM analysis")
result = cur.fetchall()
print(result)
# Out:
# [(1, 2, 0.9996267557144165, 'neutral'), (2, 3, 0.9979020357131958, 'neutral'), (3, 4, 0.9998151659965515, 'neutral'), (4, 5, 0.9930877089500427, 'neutral'), (5, 6, 0.998815655708313, 'neutral'), (6, 7, 0.9996019005775452, 'positive'), (7, 8, 0.9260686635971069, 'positive'), (8, 9, 0.9994989633560181, 'negative'), (9, 10, 0.9997492432594299, 'neutral'), (10, 11, 0.999708354473114, 'neutral'), (11, 12, 0.9996335506439209, 'neutral'), (12, 13, 0.9988706707954407, 'neutral'), (13, 14, 0.9994862079620361, 'neutral'), (14, 15, 0.9991676807403564, 'positive'), (15, 16, 0.998798131942749, 'positive'), (16, 17, 0.9997796416282654, 'neutral'), (17, 18, 0.9997734427452087, 'neutral'), (18, 19, 0.9992006421089172, 'neutral'), (19, 20, 0.999681830406189, 'neutral'), (20, 21, 0.9996622800827026, 'neutral'), (21, 22, 0.9994404911994934, 'neutral'), (22, 23, 0.999573290348053, 'neutral'), (23, 24, 0.97506183385849, 'neutral'), (24, 25, 0.9978627562522888, 'neutral'), (25, 26, 0.9996750354766846, 'neutral'), (26, 27, 0.9965741634368896, 'positive'), (27, 28, 0.9450923800468445, 'neutral'), (28, 29, 0.9996788501739502, 'neutral'), (29, 30, 0.9994257688522339, 'neutral'), (30, 31, 0.9972794651985168, 'neutral'), (31, 32, 0.9991199374198914, 'neutral'), (32, 33, 0.9983579516410828, 'positive'), (33, 34, 0.9997531771659851, 'neutral'), (34, 35, 0.9490655064582825, 'positive'), (35, 36, 0.8303812742233276, 'positive'), (36, 37, 0.9993942975997925, 'neutral'), (37, 38, 0.9997108578681946, 'positive'), (38, 39, 0.9991926550865173, 'neutral'), (39, 40, 0.9997660517692566, 'neutral'), (40, 41, 0.9996720552444458, 'neutral'), (41, 42, 0.998573899269104, 'neutral'), (42, 43, 0.6466176509857178, 'neutral'), (43, 44, 0.9996623992919922, 'neutral'), (44, 45, 0.9995124340057373, 'neutral'), (45, 46, 0.9983201622962952, 'neutral'), (46, 47, 0.8935762643814087, 'positive'), (47, 48, 0.9997557997703552, 'neutral'), (48, 49, 0.6550818085670471, 'neutral'), (49, 50, 0.9997153878211975, 'neutral'), (50, 51, 0.9997991919517517, 'neutral'), (51, 52, 0.9996479749679565, 'neutral'), (52, 53, 0.9986364245414734, 'neutral'), (53, 54, 0.9989792704582214, 'neutral'), (54, 55, 0.999573290348053, 'neutral'), (55, 56, 0.9993984699249268, 'neutral'), (56, 57, 0.8991352319717407, 'neutral'), (57, 58, 0.9997859597206116, 'positive'), (58, 59, 0.9994667172431946, 'neutral'), (59, 60, 0.9997333884239197, 'positive'), (60, 61, 0.999593198299408, 'neutral'), (61, 62, 0.9998052716255188, 'neutral'), (62, 63, 0.9995259046554565, 'neutral'), (63, 64, 0.999800980091095, 'neutral'), (64, 65, 0.9995174407958984, 'neutral'), (65, 66, 0.9994415640830994, 'neutral'), (66, 67, 0.9994660019874573, 'neutral'), (67, 68, 0.9993808269500732, 'neutral'), (68, 69, 0.9125127196311951, 'neutral'), (69, 70, 0.9996331930160522, 'neutral'), (70, 71, 0.9996265172958374, 'neutral'), (71, 72, 0.9997133612632751, 'neutral'), (72, 73, 0.9996602535247803, 'neutral'), (73, 74, 0.9996644258499146, 'neutral'), (74, 75, 0.9996215105056763, 'neutral'), (75, 76, 0.9852175116539001, 'neutral'), (76, 77, 0.9997128844261169, 'neutral'), (77, 78, 0.9994596838951111, 'neutral'), (78, 79, 0.999550998210907, 'neutral'), (79, 80, 0.9998100399971008, 'neutral'), (80, 81, 0.9997009038925171, 'neutral'), (81, 82, 0.999775230884552, 'neutral'), (82, 83, 0.9995703101158142, 'neutral'), (83, 84, 0.9996115565299988, 'neutral'), (84, 85, 0.9997239708900452, 'neutral'), (85, 86, 0.9995772242546082, 'neutral'), (86, 87, 0.9996702671051025, 'neutral'), (87, 88, 0.9996422529220581, 'neutral'), (88, 89, 0.9992471933364868, 'neutral'), (89, 90, 0.9998377561569214, 'positive'), (90, 91, 0.9996340274810791, 'neutral'), (91, 92, 0.9994189739227295, 'neutral'), (92, 93, 0.9988986253738403, 'neutral'), (93, 94, 0.9993600249290466, 'neutral'), (94, 95, 0.9985654950141907, 'neutral'), (95, 96, 0.9995954632759094, 'neutral'), (96, 97, 0.9991342425346375, 'neutral'), (97, 98, 0.9997153878211975, 'neutral'), (98, 99, 0.9993610978126526, 'neutral' ...

# %%
conn.close()
