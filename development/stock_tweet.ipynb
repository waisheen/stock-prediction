# %%
pip install gspread pandas oauth2client google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Requirement already satisfied: gspread in f:\anaconda\tmp\test-env\lib\site-packages (6.1.0)
# Requirement already satisfied: pandas in f:\anaconda\tmp\test-env\lib\site-packages (2.0.3)
# Requirement already satisfied: oauth2client in f:\anaconda\tmp\test-env\lib\site-packages (4.1.3)
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.125.0-py2.py3-none-any.whl (12.5 MB)
#                                               0.0/12.5 MB ? eta -:--:--
#                                               0.1/12.5 MB 2.6 MB/s eta 0:00:05
#      --                                       0.7/12.5 MB 9.3 MB/s eta 0:00:02
#      -----                                    1.6/12.5 MB 12.9 MB/s eta 0:00:01
#      --------                                 2.5/12.5 MB 14.5 MB/s eta 0:00:01
#      ----------                               3.3/12.5 MB 15.3 MB/s eta 0:00:01
#      -------------                            4.2/12.5 MB 15.8 MB/s eta 0:00:01
#      ----------------                         5.0/12.5 MB 16.1 MB/s eta 0:00:01
#      ------------------                       5.9/12.5 MB 16.3 MB/s eta 0:00:01
#      ---------------------                    6.7/12.5 MB 16.6 MB/s eta 0:00:01
#      ------------------------                 7.5/12.5 MB 17.2 MB/s eta 0:00:01
#      --------------------------               8.4/12.5 MB 17.3 MB/s eta 0:00:01
#      -----------------------------            9.2/12.5 MB 17.4 MB/s eta 0:00:01
#      -------------------------------         10.1/12.5 MB 17.5 MB/s eta 0:00:01
#      ----------------------------------      11.0/12.5 MB 18.7 MB/s eta 0:00:01
#      ------------------------------------    11.8/12.5 MB 18.7 MB/s eta 0:00:01
#      --------------------------------------  12.5/12.5 MB 18.2 MB/s eta 0:00:01
#      --------------------------------------- 12.5/12.5 MB 16.8 MB/s eta 0:00:00
# Collecting google-auth-httplib2
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Requirement already satisfied: google-auth-oauthlib in f:\anaconda\tmp\test-env\lib\site-packages (0.4.6)
# Requirement already satisfied: google-auth>=1.12.0 in f:\anaconda\tmp\test-env\lib\site-packages (from gspread) (2.21.0)
# Requirement already satisfied: StrEnum==0.4.15 in f:\anaconda\tmp\test-env\lib\site-packages (from gspread) (0.4.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\anaconda\tmp\test-env\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in f:\anaconda\tmp\test-env\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in f:\anaconda\tmp\test-env\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in f:\anaconda\tmp\test-env\lib\site-packages (from pandas) (1.24.4)
# Requirement already satisfied: httplib2>=0.9.1 in f:\anaconda\tmp\test-env\lib\site-packages (from oauth2client) (0.22.0)
# Requirement already satisfied: pyasn1>=0.1.7 in f:\anaconda\tmp\test-env\lib\site-packages (from oauth2client) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in f:\anaconda\tmp\test-env\lib\site-packages (from oauth2client) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in f:\anaconda\tmp\test-env\lib\site-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in f:\anaconda\tmp\test-env\lib\site-packages (from oauth2client) (1.16.0)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 (from google-api-python-client)
#   Downloading google_api_core-2.18.0-py3-none-any.whl (138 kB)
#                                               0.0/138.3 kB ? eta -:--:--
#      -------------------------------------- 138.3/138.3 kB 8.0 MB/s eta 0:00:00
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in f:\anaconda\tmp\test-env\lib\site-packages (from google-auth-oauthlib) (1.3.1)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Downloading googleapis_common_protos-1.63.0-py2.py3-none-any.whl (229 kB)
#                                               0.0/229.1 kB ? eta -:--:--
#      ------------------------------------- 229.1/229.1 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in f:\anaconda\tmp\test-env\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.19.6)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client)
#   Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#                                               0.0/48.8 kB ? eta -:--:--
#      ---------------------------------------- 48.8/48.8 kB ? eta 0:00:00
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in f:\anaconda\tmp\test-env\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in f:\anaconda\tmp\test-env\lib\site-packages (from google-auth>=1.12.0->gspread) (5.3.1)
# Requirement already satisfied: urllib3<2.0 in f:\anaconda\tmp\test-env\lib\site-packages (from google-auth>=1.12.0->gspread) (1.26.16)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in f:\anaconda\tmp\test-env\lib\site-packages (from httplib2>=0.9.1->oauth2client) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in f:\anaconda\tmp\test-env\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\anaconda\tmp\test-env\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in f:\anaconda\tmp\test-env\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in f:\anaconda\tmp\test-env\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.5.7)
# Installing collected packages: uritemplate, proto-plus, googleapis-common-protos, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed google-api-core-2.18.0 google-api-python-client-2.125.0 google-auth-httplib2-0.2.0 googleapis-common-protos-1.63.0 proto-plus-1.23.0 uritemplate-4.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from googleapiclient.discovery import build
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline
from torch.nn.functional import softmax
import torch

# %%
# define scope and obtain credentials
scope = ["https://spreadsheets.google.com/feeds",'https://www.googleapis.com/auth/spreadsheets',
         "https://www.googleapis.com/auth/drive.file","https://www.googleapis.com/auth/drive"]

# input json file
creds = ServiceAccountCredentials.from_json_keyfile_name('', scope)

# authentication
client = gspread.authorize(creds)

# %%
# Extract all stock tweet csvs
service = build('drive', 'v3', credentials=creds)
query = "mimeType='application/vnd.google-apps.spreadsheet' and name = 'stock_tweets'"

results = service.files().list(q=query,
                               spaces='drive',
                               fields='nextPageToken, files(id, name)').execute()

items = results.get('files', [])
all_data_df = pd.DataFrame()

if not items:
    print('No files found.')
else:
    for item in items:
        sh = client.open_by_key(item['id'])
        worksheet = sh.get_worksheet(0) # First worksheet
        data = worksheet.get_all_values() # Get values
    
        # Store in df
        df = pd.DataFrame(data)
        df.columns = df.iloc[0]
        df = df.iloc[1:].reset_index(drop=True)
        all_data_df = pd.concat([all_data_df, df], ignore_index=True)

all_data_df.head()
# Out:
# 0                       Date  \
# 0  2022-09-29 23:41:16+00:00
# 1  2022-09-29 23:24:43+00:00
# 2  2022-09-29 23:18:08+00:00
# 3  2022-09-29 22:40:07+00:00
# 4  2022-09-29 22:27:05+00:00
#
# 0                                              Tweet Stock Name Company Name
# 0  Mainstream media has done an amazing job at br...       TSLA  Tesla, Inc.
# 1  Tesla delivery estimates are at around 364k fr...       TSLA  Tesla, Inc.
# 2  3/ Even if I include 63.0M unvested RSUs as of...       TSLA  Tesla, Inc.
# 3  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA  Tesla, Inc.
# 4  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA  Tesla, Inc.

# %%
# Import BERT model
model_name = "ahmedrachid/FinancialBERT-Sentiment-Analysis"
tokenizer = AutoTokenizer.from_pretrained(model_name)
sentiment_pipeline = pipeline("sentiment-analysis", model=model_name, tokenizer=tokenizer)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)
print(device)
# Out:
# cuda

# %%
all_data_df['Sentiment'] = all_data_df['Tweet'].apply(lambda x: sentiment_pipeline(x))
all_data_df.head()
# Out:
# 0                       Date  \
# 0  2022-09-29 23:41:16+00:00
# 1  2022-09-29 23:24:43+00:00
# 2  2022-09-29 23:18:08+00:00
# 3  2022-09-29 22:40:07+00:00
# 4  2022-09-29 22:27:05+00:00
#
# 0                                              Tweet Stock Name Company Name  \
# 0  Mainstream media has done an amazing job at br...       TSLA  Tesla, Inc.
# 1  Tesla delivery estimates are at around 364k fr...       TSLA  Tesla, Inc.
# 2  3/ Even if I include 63.0M unvested RSUs as of...       TSLA  Tesla, Inc.
# 3  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA  Tesla, Inc.
# 4  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA  Tesla, Inc.
#
# 0                                          Sentiment
# 0  [{'label': 'neutral', 'score': 0.9954950809478...
# 1  [{'label': 'neutral', 'score': 0.9998196959495...
# 2  [{'label': 'neutral', 'score': 0.9992457628250...
# 3  [{'label': 'neutral', 'score': 0.5450521707534...
# 4  [{'label': 'neutral', 'score': 0.9839450716972...

# %%
# Get the sentiment
def extract_label(row):
    return row[0]['label']

all_data_df[['sentiment_label']] = all_data_df['Sentiment'].apply(lambda x: pd.Series(extract_label(x)))
all_data_df.head()
# Out:
# 0             Date                                              Tweet  \
# 0  Sep-29-22 23:41  Mainstream media has done an amazing job at br...
# 1  Sep-29-22 23:24  Tesla delivery estimates are at around 364k fr...
# 2  Sep-29-22 23:18  3/ Even if I include 63.0M unvested RSUs as of...
# 3  Sep-29-22 22:40  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...
# 4  Sep-29-22 22:27  @RealDanODowd @Tesla Stop trying to kill kids,...
#
# 0 Stock Name Company Name                                          Sentiment  \
# 0       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9954950809478...
# 1       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9998196959495...
# 2       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9992457628250...
# 3       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.5450521707534...
# 4       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9839450716972...
#
# 0 sentiment_label
# 0         neutral
# 1         neutral
# 2         neutral
# 3         neutral
# 4         neutral

# %%
# Standardise Date
all_data_df['Date'] = pd.to_datetime(all_data_df['Date'])
all_data_df['Date'] = all_data_df['Date'].dt.strftime('%b-%d-%y %H:%M')
all_data_df.head()
# Out:
# 0             Date                                              Tweet  \
# 0  Sep-29-22 23:41  Mainstream media has done an amazing job at br...
# 1  Sep-29-22 23:24  Tesla delivery estimates are at around 364k fr...
# 2  Sep-29-22 23:18  3/ Even if I include 63.0M unvested RSUs as of...
# 3  Sep-29-22 22:40  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...
# 4  Sep-29-22 22:27  @RealDanODowd @Tesla Stop trying to kill kids,...
#
# 0 Stock Name Company Name                                          Sentiment
# 0       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9954950809478...
# 1       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9998196959495...
# 2       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9992457628250...
# 3       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.5450521707534...
# 4       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9839450716972...

# %%
def extract_label(row):
    return row[0]['label']

all_data_df[['sentiment_label']] = all_data_df['Sentiment'].apply(lambda x: pd.Series(extract_label(x)))
all_data_df.head()
# Out:
# 0             Date                                              Tweet  \
# 0  Sep-29-22 23:41  Mainstream media has done an amazing job at br...
# 1  Sep-29-22 23:24  Tesla delivery estimates are at around 364k fr...
# 2  Sep-29-22 23:18  3/ Even if I include 63.0M unvested RSUs as of...
# 3  Sep-29-22 22:40  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...
# 4  Sep-29-22 22:27  @RealDanODowd @Tesla Stop trying to kill kids,...
#
# 0 Stock Name Company Name                                          Sentiment  \
# 0       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9954950809478...
# 1       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9998196959495...
# 2       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9992457628250...
# 3       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.5450521707534...
# 4       TSLA  Tesla, Inc.  [{'label': 'neutral', 'score': 0.9839450716972...
#
# 0 sentiment_label
# 0         neutral
# 1         neutral
# 2         neutral
# 3         neutral
# 4         neutral

# %%
all_data_df.to_csv('all_data.csv', index=False)
